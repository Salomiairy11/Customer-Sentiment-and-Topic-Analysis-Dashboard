# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from modules.data_processor import preprocess_dataframe
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[159], line 4
#       2 import pandas as pd
#       3 from sklearn.model_selection import train_test_split
# ----> 4 from modules.data_processor import preprocess_dataframe
#
# ModuleNotFoundError: No module named 'modules'

# %%
data = pd.read_pickle("../models/data_processed.pkl")

# %%
X= data['Full Review']
y=data['Sentiment']

# %%
sentiment_counts = data["Sentiment"].value_counts().sort_index()

# %%
import matplotlib.pyplot as plt

# %%
labels = ["Negative", "Neutral", "Positive"]
plt.pie(sentiment_counts,labels=labels,autopct="%.2f%%")
plt.show()

# %% [markdown]
# <h3>Since our data is imbalanced we downsize our positive sample</h3>

# %%
pip install -U imbalanced-learn
# Out:
# Requirement already satisfied: imbalanced-learn in c:\lqdigitalproject\venv\lib\site-packages (0.13.0)
# Requirement already satisfied: numpy<3,>=1.24.3 in c:\lqdigitalproject\venv\lib\site-packages (from imbalanced-learn) (2.2.6)
# Requirement already satisfied: scipy<2,>=1.10.1 in c:\lqdigitalproject\venv\lib\site-packages (from imbalanced-learn) (1.15.3)
# Requirement already satisfied: scikit-learn<2,>=1.3.2 in c:\lqdigitalproject\venv\lib\site-packages (from imbalanced-learn) (1.6.1)
# Requirement already satisfied: sklearn-compat<1,>=0.1 in c:\lqdigitalproject\venv\lib\site-packages (from imbalanced-learn) (0.1.3)
# Requirement already satisfied: joblib<2,>=1.1.1 in c:\lqdigitalproject\venv\lib\site-packages (from imbalanced-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in c:\lqdigitalproject\venv\lib\site-packages (from imbalanced-learn) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from imblearn.under_sampling import RandomUnderSampler

# %%
rus = RandomUnderSampler()

# %%
X_reshaped = X.values.reshape(-1, 1)

# %%
X_res, y_res = rus.fit_resample(X_reshaped, y)

# %%
plt.pie(y_res.value_counts(),labels=labels,autopct="%.2f%%")
plt.show()

# %% [markdown]
# <h3>Divide data into train and test sets</h3>

# %%
X_res = X_res.ravel()

# %%
X_train,X_test,y_train,y_test=train_test_split(X_res,y_res,test_size=0.2,random_state=42)

# %% [markdown]
# <h3>Creating pipleine</h3>

# %%
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression

# %%
pipeline = Pipeline([
    ('tfidf',TfidfVectorizer()),
    ('lrg',LogisticRegression())
])

# %%
pipeline.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer()), ('lrg', LogisticRegression())])

# %%
model = pipeline.fit(X_train,y_train)

# %% [markdown]
# <h3>Evaluate the model</h3>

# %%
from sklearn.metrics import accuracy_score, classification_report

# %%
y_pred = pipeline.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print(f"Model Accuracy: {accuracy:.2f}")

print(classification_report(y_test, y_pred))
# Out:
# Model Accuracy: 0.68
#               precision    recall  f1-score   support
#
#            0       0.67      0.65      0.66       312
#            1       0.56      0.61      0.58       293
#            2       0.83      0.79      0.81       277
#
#     accuracy                           0.68       882
#    macro avg       0.69      0.68      0.68       882
# weighted avg       0.68      0.68      0.68       882

# %%
import joblib

# %%
joblib.dump(value=model,filename="../models/model.pkl")
# Out:
# ['../models/model.pkl']
